# %%
def newyork(Capacity):
    totalcost=0
    for unit in units:
        while Capacity>=unit and unit!=320:
            if Capacity>=unit:
                machines1.append(key_list[val_list.index(unit)])
                Capacity = Capacity-unit
    for m in machines1:
        cost = country["NewYork"][m]
        totalcost = totalcost + cost
    totalCost1.append(totalcost)
    
    a=None
    
    for l in machines1:
        if l==a:
            continue
        else:
            c=machines1.count(l)
            newyorkmachine.append(tuple((l,c)))
        a=l
    
    
def India(Capacity):
    totalcost=0
    for unit in units:
        while Capacity>=unit and unit!=320 and unit!=None:
            if Capacity>=unit:
                machines2.append(key_list[val_list.index(unit)])
                Capacity = Capacity-unit
    for m in machines2:
        cost = country["NewYork"][m]
        totalcost = totalcost + cost
    totalCost2.append(totalcost)
    
    a=None
    
    for l in machines2:
        if l==a:
            continue
        else:
            c=machines2.count(l)
            indiamachine.append(tuple((l,c)))
        a=l
        
        
                
def China(Capacity):
    totalcost=0
    for unit in units:
        while Capacity>=unit and unit!=320 and unit!=None:
            if Capacity>=unit:
                machines3.append(key_list[val_list.index(unit)])
                Capacity = Capacity-unit
    for m in machines3:
        cost = country["NewYork"][m]
        totalcost = totalcost + cost
    totalCost3.append(totalcost)
    
    a=None
    
    for l in machines3:
        if l==a:
            continue
        else:
            c=machines3.count(l)
            chinamachine.append(tuple((l,c)))
        a=l
        

        
        
        
        

Capacity = int("Enter the Capacity")
Hours = int("Enter number of Hours")

units = [10,20,40,80,160,320]
units.sort(reverse=True)
n=len(units)






country = { "NewYork" : {'Large':120,'xLarge':230,'2xLarge':450,'4xLarge':774,'8xLarge':1400,'10xLarge':2820},
            "India" : {'Large':140,'xLarge':None,'2xLarge':413,'4xLarge':890,'8xLarge':1300,'10xLarge':2970},
            "China" :  {'Large':110,'xLarge':200,'2xLarge':None,'4xLarge':670,'8xLarge':1180,'10xLarge':None}
          }
machines = {'Large':10,'xLarge':20,'2xLarge':40,'4xLarge':80,'8xLarge':160,'10xLarge':320}
key_list = list(machines.keys())
val_list = list(machines.values()) 

machines1=[]
newyorkmachine=[]
totalCost1=[]
machines2=[]
indiamachine=[]
totalCost2=[]
machines3=[]
chinamachine=[]
totalCost3=[]


#for newyork

newyork(Capacity)
#for India
India(Capacity)
#for China
China(Capacity)
            

            
solution = {'output':[{"region":"Newyork",'totalcost':totalCost1,'machines':newyorkmachine},
                     {"region":"India",'totalcost':totalCost2,'machines':indiamachine},
                      {"region":"China",'totalcost':totalCost3,'machines':chinamachine}]
           }
                      
print(solution)
# Out:
# {'output': [{'region': 'Newyork', 'totalcost': [10150], 'machines': [('8xLarge', 7), ('xLarge', 1), ('Large', 1)]}, {'region': 'India', 'totalcost': [10150], 'machines': [('8xLarge', 7), ('xLarge', 1), ('Large', 1)]}, {'region': 'China', 'totalcost': [10150], 'machines': [('8xLarge', 7), ('xLarge', 1), ('Large', 1)]}]}

# %%
# Out:
# [(1, 1), (2, 3), (2, 3), (2, 3), (5, 1)]
